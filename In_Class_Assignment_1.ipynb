# %% [markdown]
# <a href="https://colab.research.google.com/github/cmc713/BTE320-F/blob/main/In_Class_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter Sales($):"))
#Asking the user for sales value

COGS = sales * .4
#COGS is 40% of Sales

gross_profit = sales - COGS
#This calculates Gross Profit



tax_rate = (float(input("Enter Tax-Rate(%):")))/100

taxes = gross_profit * tax_rate
net_income = gross_profit - taxes

print("\nSample Income Statment: \n")

print(f"Sales: ${sales:.2f}")
print(f"COGS: ${COGS:.2f}")
print(f"Gross Profit: ${gross_profit:.2f}")
print(f"Taxes: ${taxes:.2f}")
print(f"Net Income: ${net_income:.2f}")
# Out:
# Enter Sales($):12000
# Enter Tax-Rate(%):30
#
# Sample Income Statment:
#
# Sales: $12000.00
# COGS: $4800.00
# Gross Profit: $7200.00
# Taxes: $2160.00
# Net Income: $5040.00
